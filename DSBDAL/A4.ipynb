# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np  
# df=read_csv('') 
df=sns.load_dataset("titanic")  
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info() 
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# survived         0
# pclass           0
# sex              0
# ...

# %%
# Drop rows with null values in the "Age" column
df = df.dropna(subset=['age'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     714 non-null    int64
#  1   pclass       714 non-null    int64
#  2   sex          714 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        714 non-null    int64
#  5   parch        714 non-null    int64
#  6   fare         714 non-null    float64
#  7   embarked     712 non-null    object
#  8   class        714 non-null    category
#  9   who          714 non-null    object
#  10  adult_male   714 non-null    bool
#  11  deck         184 non-null    category
#  12  embark_town  712 non-null    object
#  13  alive        714 non-null    object
#  14  alone        714 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 70.2+ KB

# %%
df=df.astype({
    'age':'int64'
})

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age               int64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# A count plot of Passenger Class in titanic  
sns.countplot(data=df, x='pclass' )
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=df, x='pclass', hue='survived')

plt.xlabel('Passenger Class')

plt.legend(title='age')

plt.show()

# %%
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analogous to a histogram. 
# KDE represents the data using a continuous probability density curve in one or more dimensions.  
sns.histplot(data=df, x='age', bins=10, kde=True, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Histogram of Passenger Ages')
plt.show()

# %%
sns.countplot(data=df, x='pclass')
# plt.xlabel('Passenger Class')
# plt.ylabel('Count')
# plt.title('Passenger Class Distribution')
# plt.show()
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
# Barplot can plot graph of two columns but countplot takes in in x values as y represents the count the x param
sns.barplot(data=df, x='age', hue='survived')     
plt.xlabel("Gender of Passengers")  
plt.ylabel("The Survival")  
plt.title("gender and survive") 
plt.show()

# %%
sns.barplot(x='sex', y='survived', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(data=df, x='pclass', y='survived')
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %%
sns.boxplot(data=df, x='sex', y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data=df, x='sex', y='age', hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(data=df, x='pclass', y='fare', edgecolor='black')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.histplot(x='fare', data=df, bins=20)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.boxplot(data=df, x='sex', y='age', hue='survived')        
plt.title("Inference of the survival of passnegers by age and gender")
# Out:
# Text(0.5, 1.0, 'Inference of the survival of passnegers by age and gender')

# %%
sns.scatterplot(x='pclass', y='age', hue='survived', data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.scatterplot(x='fare', y='age', hue='survived', data=df)
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.scatterplot(x='age', y='fare', hue='survived', data=df)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.violinplot(data=df, x='survived', y='age')
plt.xlabel('Survived')
plt.ylabel('Age')
plt.title('Age Distribution by Survival')
plt.show()

# %%
sns.violinplot(data=df, x='pclass', y='age', hue='survived')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>
