# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.groupby(['species'])['sepal_width'].describe()
# Out:
#             count   mean       std  min    25%  50%    75%  max
# species
# setosa       50.0  3.428  0.379064  2.3  3.200  3.4  3.675  4.4
# versicolor   50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# virginica    50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8

# %%
df.groupby(['species'])['sepal_width', 'petal_length'].describe()
# Out:
# <ipython-input-14-7b304dd7981d>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['species'])['sepal_width', 'petal_length'].describe()
#            sepal_width                                                \
#                  count   mean       std  min    25%  50%    75%  max
# species
# setosa            50.0  3.428  0.379064  2.3  3.200  3.4  3.675  4.4
# versicolor        50.0  2.770  0.313798  2.0  2.525  2.8  3.000  3.4
# virginica         50.0  2.974  0.322497  2.2  2.800  3.0  3.175  3.8
#
#            petal_length
#                   count   mean       std  min  25%   50%    75%  max
# species
# setosa             50.0  1.462  0.173664  1.0  1.4  1.50  1.575  1.9
# versicolor         50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# virginica          50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %%
grouped=df.groupby(['species'])['sepal_width', 'petal_length'].median() 
grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, setosa to virginica
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_width   3 non-null      float64
#  1   petal_length  3 non-null      float64
# dtypes: float64(2)
# memory usage: 72.0+ bytes
# <ipython-input-16-853352f9c5a4>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped=df.groupby(['species'])['sepal_width', 'petal_length'].median()

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
sns.histplot(data=df, x='sepal_width', kde=True, bins=20, edgecolor='black')
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=df, x='sepal_length', kde=True, bins=20, edgecolor='black')
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
df.hist() 

# Sepal Lenght and Width are normal distribution
# Petal lenght and width are bimodal distribution
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
# Create boxplots for each feature
# data.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
df.plot(kind='box')

# Show the plot
plt.show()  

# Petal Lenght and Petal width are negetively skewed 
# Sepal Width has outliers with dots indicating, but overal data is normal

# %%
# Line plot
df.plot(kind='line')

# Bar plot
df.plot(kind='bar')

# Histogram
df.plot(kind='hist')

# Box plot
df.plot(kind='box')
# Out:
# <Axes: >

# %%
sns.boxplot(data=df, x='species', y='sepal_width')
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>
